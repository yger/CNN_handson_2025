# %% [markdown]
# # TP M2 CNN

# %% [markdown]
# ## Questions:

# %% [markdown]
# ### What are the pros and cons of calcium imaging vs electrophyisiology?<br>

# %% [markdown]
# Please answer

# %% [markdown]
# ### What are the open challenges for spike sorting?<br>

# %% [markdown]
# Please answer

# %% [markdown]
# ### What are the key algorithmic steps involved in a typical spike sorting pipeline nowadays?

# %% [markdown]
# Please answer

# %% [markdown]
# ## Hands-on practise

# %%
import spikeinterface.full as si

# %%
YOURBIRTHDATE = 11101981
rec, sorting = si.generate_ground_truth_recording(num_channels=64, num_units=64, seed=YOURBIRTHDATE)

# %% [markdown]
# ### Visualize the recording with si.plot_traces()

# %%
### TO DO ###

# %% [markdown]
# ### Visualize the probe layout si.plot_probe_map()

# %%
### TO DO ###

# %% [markdown]
# ### Spike sort this recording using the si.run_sorter() command and the sorter of your choice (installed on your machine)

# %%
### TO DO ###

# %% [markdown]
# ### Once you obtained a sorting, try to create a sorting_analyzer with si.create_sorting_analyzer(). Compute some extensions for this analyzer (via compute([""])), and visualize them with appropriate commands

# %%
### TO DO ###

# %% [markdown]
# ### Try to get some quality metrics and let me know what are, according to you, the good cells found

# %%
### TO DO ###

# %% [markdown]
# ### Can you tell me what are the key properties of the good neurons, w.r.t firing rate, ISI, SNR?

# %%
### TO DO ###

# %% [markdown]
# ### Do you have the feeling that some cells in the recordings are oversplitted and should be merged? Why, and can you comment about it?

# %%
### TO DO ###

# %% [markdown]
# ### For advanced users, have a look to the comparison object si.compare_sorter_to_ground_truth() to get a confirmation that the cells you think were good are actually real neurons. Are there any discrepancies? Why?

# %%
### TO DO ###
