# %% [markdown]
# ### In-vitro data

# %%
from pathlib import Path
import spikeinterface.full as si

# %matplotlib widget

# %%
base_data_folder = Path("/home/samuel/DataSpikeSorting/data_cns_lyon_2025/")
working_folder = Path("/home/samuel/DataSpikeSorting/data_cns_lyon_2025/results")


recording_stem = "human_ngn2_100K_c_55D"
recording_name = f"{recording_stem}.brw"

results_folder = working_folder / recording_stem

# %%
recording = si.read_biocam(base_data_folder / recording_name)

# %%
recording = recording.remove_channels(recording.channel_ids[:1])
recording
# Out:
# ChannelSliceRecording: 4095 channels - 10103.075195 Hz - 1 segments - 1,211,049 samples
#                        119.87s (2.00 minutes) - uint16 dtype - 9.24 GiB

# %%
recording
# Out:
# ChannelSliceRecording: 4095 channels - 10103.075195 Hz - 1 segments - 1,211,049 samples
#                        119.87s (2.00 minutes) - uint16 dtype - 9.24 GiB

# %%
recording = si.unsigned_to_signed(recording, bit_depth=12)

# %%
recording
# Out:
# UnsignedToSignedRecording: 4095 channels - 10103.075195 Hz - 1 segments - 1,211,049 samples
#                            119.87s (2.00 minutes) - int16 dtype - 9.24 GiB

# %%
recording_processed = si.bandpass_filter(recording, freq_max=5000)
recording_processed = si.common_reference(recording_processed)

# %%
from spikeinterface.sortingcomponents.peak_detection import detect_peaks
from spikeinterface.sortingcomponents.peak_localization import localize_peaks

# %%
si.set_global_job_kwargs(n_jobs=-1, chunk_duration="0.5s")

# %%
# noise_levels =si?.

# %%
peaks = detect_peaks(
    recording_processed,
    method="locally_exclusive",
    detect_threshold=6.,
    exclude_sweep_ms=0.1,
    radius_um=75.,
)
# Out:
# /home/samuel/Documents/SpikeInterface/spikeinterface/src/spikeinterface/sortingcomponents/peak_detection/main.py:62: UserWarning: The signature of detect_peaks() has changed, now method_kwargs and job_kwargs are dinstinct params.This warning will raise an error in version 0.105.0
#   warnings.warn(
# noise_level (workers: 12 processes):   0%|          | 0/20 [00:00<?, ?it/s]
# detect peaks (locally_exclusive) (workers: 12 processes):   0%|          | 0/240 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 peaks = detect_peaks(
#       2     recording_processed,
#       3     method="locally_exclusive",
#       4     detect_threshold=6.,
#       5     exclude_sweep_ms=0.1,
#       6     radius_um=75.,
#       7 )
#
# File ~/Documents/SpikeInterface/spikeinterface/src/spikeinterface/sortingcomponents/peak_detection/main.py:109, in detect_peaks(recording, method, method_kwargs, pipeline_kwargs, verbose, job_kwargs, **old_kwargs)
#     106     pipeline_kwargs = dict()
#     107 job_name = f"detect peaks ({method})"
# --> 109 outs = run_node_pipeline(
#     110     recording, nodes, job_kwargs, job_name=job_name, squeeze_output=True, verbose=verbose, **pipeline_kwargs
#     111 )
#     112 return outs
#
# File ~/Documents/SpikeInterface/spikeinterface/src/spikeinterface/core/node_pipeline.py:630, in run_node_pipeline(recording, nodes, job_kwargs, job_name, gather_mode, gather_kwargs, squeeze_output, folder, names, verbose, skip_after_n_peaks, recording_slices)
#     617 init_args = (recording, nodes, skip_after_n_peaks_per_worker)
#     619 processor = ChunkRecordingExecutor(
#     620     recording,
#     621     _compute_peak_pipeline_chunk,
#    (...)
#     627     **job_kwargs,
#     628 )
# --> 630 processor.run(recording_slices=recording_slices)
#     632 outs = gather_func.finalize_buffers(squeeze_output=squeeze_output)
#     633 return outs
#
# File ~/Documents/SpikeInterface/spikeinterface/src/spikeinterface/core/job_tools.py:536, in ChunkRecordingExecutor.run(self, recording_slices)
#     531 if self.progress_bar:
#     532     results = tqdm(
#     533         results, desc=f"{self.job_name} (workers: {n_jobs} processes)", total=len(recording_slices)
#     534     )
# --> 536 for res in results:
#     537     if self.handle_returns:
#     538         returns.append(res)
#
# File ~/.venvs/py3.12/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/.venvs/py3.12/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /usr/lib/python3.12/concurrent/futures/process.py:642, in _chain_from_iterable_of_lists(iterable)
#     636 def _chain_from_iterable_of_lists(iterable):
#     637     """
#     638     Specialized implementation of itertools.chain.from_iterable.
#     639     Each item in *iterable* should be a list.  This function is
#     640     careful not to keep references to yielded objects.
#     641     """
# --> 642     for element in iterable:
#     643         element.reverse()
#     644         while element:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.hist(peaks['amplitude'], bins=500)
# Out:
# (array([4.0000e+00, 2.9000e+01, 7.0000e+00, 0.0000e+00, 1.0000e+00,
#         2.5700e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+00, 2.9000e+01,
#         0.0000e+00, 8.0000e+00, 0.0000e+00, 2.5700e+02, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+00,
#         2.8000e+01, 9.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         2.5700e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+02,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 6.0000e+00, 2.9000e+01, 5.0000e+00,
#         0.0000e+00, 0.0000e+00, 2.5800e+02, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 7.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 3.0000e+00, 4.0000e+00, 0.0000e+00, 3.0000e+00,
#         4.0000e+00, 2.0000e+00, 0.0000e+00, 6.0000e+00, 1.0000e+00,
#         5.0000e+00, 0.0000e+00, 3.0000e+00, 1.0000e+00, 2.0000e+00,
#         0.0000e+00, 6.0000e+00, 9.0000e+00, 6.0000e+00, 0.0000e+00,
#         3.0000e+00, 5.0000e+00, 3.0000e+00, 0.0000e+00, 7.0000e+00,
#         9.0000e+00, 8.0000e+00, 0.0000e+00, 6.0000e+00, 5.0000e+00,
#         5.0000e+00, 0.0000e+00, 6.0000e+00, 9.0000e+00, 0.0000e+00,
#         6.0000e+00, 2.0000e+00, 3.0000e+00, 0.0000e+00, 5.0000e+00,
#         4.0000e+00, 3.0000e+00, 0.0000e+00, 7.0000e+00, 9.0000e+00,
#         7.0000e+00, 0.0000e+00, 4.0000e+00, 5.0000e+00, 5.0000e+00,
#         0.0000e+00, 4.0000e+00, 8.0000e+00, 3.0000e+00, 0.0000e+00,
#         7.0000e+00, 7.0000e+00, 6.0000e+00, 0.0000e+00, 4.1000e+01,
#         1.6000e+01, 6.0000e+00, 0.0000e+00, 2.6200e+02, 7.0000e+00,
#         7.0000e+00, 0.0000e+00, 1.0000e+01, 5.0000e+00, 9.0000e+00,
#         0.0000e+00, 6.0000e+00, 6.0000e+00, 1.0000e+01, 0.0000e+00,
#         7.0000e+00, 5.0000e+00, 0.0000e+00, 8.0000e+00, 5.0000e+00,
#         1.4000e+01, 0.0000e+00, 1.0000e+01, 7.0000e+00, 9.0000e+00,
#         0.0000e+00, 1.4000e+01, 7.0000e+00, 1.9000e+01, 0.0000e+00,
#          -29.272,  -28.528,  -27.784,  -27.04 ,  -26.296,  -25.552,
#          -24.808,  -24.064,  -23.32 ,  -22.576,  -21.832,  -21.088,
#          -20.344,  -19.6  ,  -18.856,  -18.112,  -17.368,  -16.624,
#          -15.88 ,  -15.136,  -14.392,  -13.648,  -12.904,  -12.16 ,
#          -11.416,  -10.672,   -9.928,   -9.184,   -8.44 ,   -7.696,
#           -6.952,   -6.208,   -5.464,   -4.72 ,   -3.976,   -3.232,
#           -2.488,   -1.744,   -1.   ]),
#  <BarContainer object of 500 artists>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
si.plot_peak_activity(recording, peaks, color_range=[0, 10])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sorting =si.NumpySorting.from_peaks(peaks, recording.sampling_frequency, recording.channel_ids)
sorting
# Out:
# NumpySorting: 4096 units - 1 segments - 10.1kHz

# %%
si.plot_rasters(sorting, unit_ids=sorting.unit_ids[:20])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sorting_HS = si.run_sorter(sorter_name="herdingspikes", recording=recording_processed, 
                           folder=working_folder / recording_name / "sorter_HS",
                           verbose=True, remove_existing_folder=True)

# %%
import numpy as np

# %%
active_chan, speak_count = np.unique(peaks['channel_index'],return_counts=True)

# %%
active_chan, speak_count
# Out:
# (array([   0,    2,    5, ..., 4091, 4092, 4093]),
#  array([37510,     5,     7, ...,   158,   560,     1]))

# %%
very_active_channel = active_chan[speak_count>50]
very_active_channel

va_chan_ids = recording.channel_ids[very_active_channel]
va_chan_ids
# Out:
# array(['1', '9', '19', '42', '43', '52', '55', '81', '89', '96', '102',
#        '106', '131', '145', '201', '202', '220', '221', '261', '284',
#        '285', '306', '331', '351', '352', '365', '371', '375', '376',
#        '402', '413', '434', '435', '436', '445', '446', '447', '456',
#        '457', '476', '498', '499', '500', '504', '542', '543', '562',
#        '565', '568', '570', '593', '594', '595', '604', '606', '617',
#        '619', '620', '631', '632', '634', '654', '657', '658', '659',
#        '683', '684', '706', '710', '718', '744', '747', '759', '765',
#        '773', '775', '861', '862', '874', '887', '900', '926', '929',
#        '934', '940', '946', '947', '948', '963', '964', '968', '972',
#        '979', '983', '988', '992', '993', '994', '1011', '1016', '1043',
#        '1052', '1058', '1064', '1065', '1066', '1069', '1073', '1077',
#        '1093', '1107', '1108', '1144', '1156', '1157', '1158', '1188',
#        '1196', '1212', '1222', '1223', '1258', '1259', '1268', '1272',
#        '1278', '1293', '1295', '1296', '1299', '1321', '1322', '1323',
#        '1324', '1332', '1333', '1341', '1342', '1349', '1350', '1351',
#        '1361', '1363', '1372', '1373', '1383', '1384', '1385', '1386',
#        '1387', '1394', '1405', '1413', '1414', '1415', '1425', '1438',
#        '1450', '1451', '1453', '1458', '1459', '1462', '1469', '1470',
#        '1472', '1478', '1479', '1497', '1505', '1516', '1522', '1523',
#        '1524', '1525', '1532', '1542', '1551', '1567', '1573', '1609',
#        '1618', '1630', '1631', '1650', '1655', '1694', '1727', '1756',
#        '1768', '1778', '1796', '1801', '1818', '1819', '1820', '1821',
#        '1826', '1832', '1862', '1865', '1870', '1882', '1884', '1885',
#        '1890', '1900', '1906', '1910', '1918', '1923', '1934', '1936',
#        '1949', '1963', '1969', '1981', '1988', '1989', '1998', '2000',
#        '2001', '2002', '2010', '2026', '2027', '2030', '2033', '2034',
#        '2040', '2045', '2050', '2053', '2075', '2091', '2101', '2109',
#        '2114', '2118', '2122', '2123', '2126', '2139', '2158', '2163',
#        '2165', '2180', '2183', '2193', '2194', '2195', '2205', '2206',
#        '2227', '2228', '2256', '2257', '2271', '2272', '2286', '2302',
#        '2308', '2312', '2343', '2344', '2346', '2390', '2399', '2412',
#        '2414', '2418', '2423', '2441', '2454', '2462', '2465', '2466',
#        '2471', '2472', '2476', '2477', '2481', '2482', '2496', '2520',
#        '2534', '2545', '2546', '2550', '2568', '2569', '2583', '2584',
#        '2609', '2631', '2632', '2637', '2641', '2642', '2654', '2655',
#        '2664', '2673', '2675', '2678', '2679', '2681', '2686', '2687',
#        '2694', '2695', '2700', '2704', '2705', '2706', '2717', '2721',
#        '2743', '2750', '2751', '2752', '2768', '2769', '2786', '2789',
#        '2806', '2815', '2846', '2847', '2853', '2857', '2889', '2894',
#        '2930', '2931', '2941', '2942', '2960', '2968', '2984', '2991',
#        '3006', '3024', '3025', '3032', '3033', '3035', '3039', '3040',
#        '3041', '3056', '3059', '3065', '3071', '3074', '3075', '3084',
#        '3092', '3096', '3099', '3101', '3102', '3110', '3117', '3120',
#        '3142', '3153', '3154', '3175', '3180', '3181', '3182', '3184',
#        '3190', '3194', '3205', '3214', '3237', '3243', '3244', '3245',
#        '3262', '3265', '3277', '3278', '3280', '3292', '3308', '3316',
#        '3318', '3327', '3332', '3342', '3353', '3362', '3367', '3382',
#        '3383', '3390', '3391', '3396', '3417', '3429', '3430', '3442',
#        '3449', '3459', '3460', '3461', '3464', '3470', '3481', '3482',
#        '3494', '3512', '3524', '3525', '3527', '3529', '3534', '3550',
#        '3553', '3574', '3575', '3578', '3598', '3599', '3610', '3634',
#        '3665', '3670', '3690', '3691', '3699', '3708', '3709', '3711',
#        '3723', '3754', '3755', '3756', '3764', '3780', '3788', '3795',
#        '3797', '3802', '3804', '3818', '3820', '3821', '3824', '3831',
#        '3844', '3852', '3868', '3891', '3907', '3908', '3910', '3946',
#        '3954', '3964', '3965', '3966', '3972', '3973', '3980', '3989',
#        '3995', '4010', '4011', '4021', '4026', '4028', '4029', '4036',
#        '4037', '4038', '4040', '4041', '4042', '4044', '4047', '4048',
#        '4049', '4050', '4053', '4056', '4072', '4083', '4084', '4085',
#        '4092', '4093'], dtype='<U64')

# %%
si.plot_traces(recording, channel_ids=va_chan_ids[1:4])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sorting_HS

# %%
analyzer = si.create_sorting_analyzer(sorting_HS, recording_processed)
extension_list = ["random_spikes", "templates", "unit_locations", "correlograms", "template_similarity", "spike_amplitudes"]
analyzer.compute(extension_list)

# %%
si.plot_unit_templates(analyzer, backend="ipywidgets")

# %%
si.plot_rasters(analyzer)

# %%
potential_merges = si.compute_merge_unit_groups(analyzer, preset="x_contaminations")

# %%
print(len(potential_merges))

# %%
si.plot_potential_merges(analyzer, potential_merges, backend="ipywidgets")
